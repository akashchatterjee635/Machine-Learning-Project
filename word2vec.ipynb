# %%
# !pip install gensim
# !pip install python-Levenshtein
# Out:
# ...
#      ---------------------------------------- 0.0/59.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/59.0 kB 640.0 kB/s eta 0:00:01
#      -------------------------- ----------- 41.0/59.0 kB 326.8 kB/s eta 0:00:01
#      -------------------------- ----------- 41.0/59.0 kB 326.8 kB/s eta 0:00:01
#      -------------------------- ----------- 41.0/59.0 kB 326.8 kB/s eta 0:00:01
#      -------------------------- ----------- 41.0/59.0 kB 326.8 kB/s eta 0:00:01
#      -------------------------- ----------- 41.0/59.0 kB 326.8 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/59.0 kB 137.9 kB/s eta 0:00:01
#      -------------------------------------- 59.0/59.0 kB 148.1 kB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...

# %%
import pandas as pd
import numpy as np
df=pd.read_json("D:\Cell_Phones_and_Accessories_5.json", lines=True)

# %%
df.head()
# Out:
#        reviewerID        asin      reviewerName helpful  \
# 0  A30TL5EWN6DFXT  120401325X         christina  [0, 0]
# 1   ASY55RVNIL0UD  120401325X          emily l.  [0, 0]
# 2  A2TMXE2AFO7ONB  120401325X             Erica  [0, 0]
# 3   AWJ0WZQYMYFQ4  120401325X                JM  [4, 4]
# 4   ATX7CZYFXI1KW  120401325X  patrice m rogoza  [2, 3]
#
#                                           reviewText  overall  \
# 0  They look good and stick good! I just don't li...        4
# 1  These stickers work like the review says they ...        5
# 2  These are awesome and make my phone look so st...        5
# 3  Item arrived in great time and was in perfect ...        4
# 4  awesome! stays on, and looks great. can be use...        5
#
#                                      summary  unixReviewTime   reviewTime
# 0                                 Looks Good      1400630400  05 21, 2014
# 1                      Really great product.      1389657600  01 14, 2014
# ...

# %%
df.reviewText.shape
# Out:
# (194439,)

# %% [markdown]
# !pip install gensim
# review_text = df.reviewText[:50000].apply(gensim.utils.simple_preprocess)

# %%
# !pip install gensim --user

# %% [markdown]
# review_text = df.reviewText[:50000].apply(gensim.utils.simple_preprocess)

# %% [markdown]
# !pip install gensim

# %%
import gensim
review_text = df.reviewText[:50000].apply(gensim.utils.simple_preprocess)

# %%
review_text
# Out:
# 0        [they, look, good, and, stick, good, just, don...
# 1        [these, stickers, work, like, the, review, say...
# 2        [these, are, awesome, and, make, my, phone, lo...
# 3        [item, arrived, in, great, time, and, was, in,...
# 4        [awesome, stays, on, and, looks, great, can, b...
#                                ...
# 49995    [was, sceptical, about, these, batteries, beca...
# 49996    [these, batteries, have, been, great, replacem...
# 49997    [it, works, the, thunderbolt, eats, battery, l...
# 49998    [these, batteries, have, held, up, for, over, ...
# 49999    [ve, had, my, htc, thunderbolt, for, almost, y...
# Name: reviewText, Length: 50000, dtype: object

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2,
    workers=4,
)

# %%
model.build_vocab(review_text, progress_per=1000)

# %%
model.train(review_text, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (15990547, 21792175)

# %%
model.wv.most_similar("bad")
# Out:
# [('terrible', 0.6100783348083496),
#  ('shabby', 0.5611602067947388),
#  ('good', 0.5542491674423218),
#  ('horrible', 0.5155312418937683),
#  ('fault', 0.5002713799476624),
#  ('big', 0.4910736680030823),
#  ('poor', 0.4834918975830078),
#  ('obvious', 0.48200172185897827),
#  ('okay', 0.47501546144485474),
#  ('funny', 0.4750044047832489)]

# %% [markdown]
# model.wv.similarity(w1="great", w2="good")

# %% [raw]
# inval=df['overall'].map(lambda x: x>0)
# inval

# %%
# Out:
# 194439
